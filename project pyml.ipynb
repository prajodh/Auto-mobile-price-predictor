# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data Importing

# %%
auto = pd.read_csv("Automobile price data _Raw_.csv")

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# ## Initial data cleaning

# %%
auto['num-of-doors'].replace('?','four',inplace=True)

# %%
newauto= auto.replace('?',np.nan)

# %%
newauto
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
newauto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
newauto["normalized-losses"] = pd.to_numeric(newauto["normalized-losses"])
newauto["price"] = pd.to_numeric(newauto["price"])
newauto["horsepower"] = pd.to_numeric(newauto["horsepower"])
newauto["peak-rpm"] = pd.to_numeric(newauto["peak-rpm"])
newauto["bore"] = pd.to_numeric(newauto["bore"])
newauto["stroke"] = pd.to_numeric(newauto["stroke"])

# %%
newauto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
newauto['normalized-losses']=newauto['normalized-losses'].fillna(value=newauto['normalized-losses'].mean(skipna=True))
newauto['price']=newauto['price'].fillna(value=newauto['price'].mean(skipna=True))
newauto['horsepower']=newauto['horsepower'].fillna(value=newauto['horsepower'].mean(skipna=True))
newauto['peak-rpm']=newauto['peak-rpm'].fillna(value=newauto['peak-rpm'].mean(skipna=True))
newauto['bore']=newauto['bore'].fillna(value=newauto['bore'].mean(skipna=True))
newauto['stroke']=newauto['stroke'].fillna(value=newauto['stroke'].mean(skipna=True))

# %%
newauto.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
newauto
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# ## Exploratory Data analysis

# %%
sns.distplot(newauto['stroke'])#most of the cars have 3 to 3.5 stroke

# %%
sns.barplot(x='num-of-cylinders',y='horsepower',data=newauto)#higher the no of cylinders higher is the horsepower

# %%
sns.barplot(x='fuel-system',y='highway-mpg',data=newauto)#the 2bbl,1bbl and idi fuel systems are best suited for higher milages

# %%
sns.boxplot(x="drive-wheels", y="peak-rpm", data=newauto,palette='rainbow')#the fwd has a larger peakrpm range

# %%
sns.lmplot(x="height", y="city-mpg", data=newauto)#cars with height ranging from 52 to54 have an avg cith mpg of 20 to 25

# %%
sns.stripplot(x="engine-type", y="horsepower", data=newauto,jitter=True)#most of the cars belong to ohc catogery of engine type and ohvc usually has a higher hrsepower range comparitvily

# %%
sns.distplot(newauto['curb-weight'])#most of the the cars have an curb weight ranging from 1750 to 3250

# %%
sns.barplot(x='body-style',y='price',data=newauto)#hardtop and convertibles are more expensive that the other bodystyles

# %% [markdown]
# ## Data cleaning

# %%
newauto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in list(newauto.columns):
    if newauto[i].dtype=='object':
        newauto[i]=le.fit_transform(newauto[i])

# %%
newauto
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3              122.0     0          1           0             1
# 1            3              122.0     0          1           0             1
# 2            1              122.0     0          1           0             1
# 3            2              164.0     1          1           0             0
# 4            2              164.0     1          1           0             0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0    21          1           0             0
# 201         -1               95.0    21          1           1             0
# 202         -1               95.0    21          1           0             0
# 203         -1               95.0    21          0           1             0
# 204         -1               95.0    21          1           1             0
#
# ...

# %% [markdown]
# ## Preparing data for training

# %%
y=newauto['price']
X=newauto.drop(['price'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=101,test_size=0.3)

# %% [markdown]
# ## ML models used

# %% [markdown]
# ## 1.Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
Lr=LinearRegression()
Lr.fit(X_train,y_train)
pred1=lr.predict(X_test)
score_lr=r2_score(y_test,pred_1)

# %%
score_lr
# Out:
# 0.8021470958755839

# %%
plt.scatter(y_test,pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# ## 2.Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfg=RandomForestRegressor()
rfg.fit(X_train,y_train)
pred2=rfg.predict(X_test)
score_rfr=r2_score(y_test,pred2)

# %%
score_rfr
# Out:
# 0.9028826563791924

# %% [markdown]
# ## 3.Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor
br=BaggingRegressor()
br.fit(X_train,y_train)
pred3=br.predict(X_test)
score_br=r2_score(y_test,pred3)

# %%
score_br
# Out:
# 0.9035142934949485
